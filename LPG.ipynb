# %%
import pandas as pd

# %%
df = pd.read_csv('한국가스안전공사_전국 LPG 충전소 현황_20200824.csv', sep=",")

# %%
df.head()
# Out:
#     행정 구역        업소명                    소재지          전화번호           관리구분
# 0  서울 강남구    강남복지충전소  서울 강남구 자곡동 373-1 (1층)   02-445-3300          자동차충전
# 1  서울 강남구    (주)진양가스       서울 강남구 도곡동 552-4  02-3463-6811          자동차충전
# 2  서울 강남구  대치에너지주식회사       서울 강남구 대치동 27-15  02-3412-2828          자동차충전
# 3  서울 강남구   남서울가스(주)        서울 강남구 대치동 21-1  02-3411-4411  용기+자동차+13kg용기
# 4  서울 강남구   (주)수서에너지     서울 강남구 자곡동 204-1.3   02-445-1083          자동차충전

# %%
dj=df[df['행정 구역'].str.contains('대전')]
dj
# Out:
#       행정 구역                   업소명                                  소재지  \
# 320  대전 대덕구         (주)중앙그린에너지2호점           대전 대덕구 상서동 441-3,443-9,441
# 321  대전 대덕구              대화LPG충전소                    대전 대덕구 대화동 16-140
# 322  대전 대덕구              대전LPG충전소                       대전 대덕구 대화동 3-1
# 323  대전 대덕구                신탄진충전소                    대전 대덕구 상서동 349-12
# 324  대전 대덕구                 상서충전소                       대전 대덕구 상서동 440
# 325  대전 대덕구            대덕밸리LPG충전소                     대전 대덕구 평촌동 226-5
# 326  대전 대덕구        (주)회덕아이씨주유소충전소                     대전 대덕구 신대동 433-2
# 327  대전 대덕구                 대덕충전소                    대전 대덕구 대화동 549-16
# 328  대전 대덕구            대화공단엘피지충전소                  대전 대덕구 읍내동 511외 4필지
# 329  대전 대덕구              공단LPG충전소                    대전 대덕구 신일동 1684-1
# 330  대전 대덕구              우성LPG충전소                     대전 대덕구 연축동 294-2
# 331  대전 대덕구                동대전충전소              대전 대덕구 오정동 432-1, 432-8
# ...

# %%
import geocoder
import openpyxl
import time

# %%
exelFile = openpyxl.load_workbook(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-44394d1d9fdb> in <module>
# ----> 1 exelFile = openpyxl.load_workbook(df)
#
# C:\python\anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     311     """
#     312     reader = ExcelReader(filename, read_only, keep_vba,
# --> 313                         data_only, keep_links)
#     314     reader.read()
#     315     return reader.wb
#
# C:\python\anaconda3\lib\site-packages\openpyxl\reader\excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
# ...

# %%
TEST
